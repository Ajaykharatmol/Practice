# %%
import pandas as pd
import seaborn as sns
df1 =  pd.read_csv("C:\\Users\\ACEFR\\CSV Files\\glass.csv")
df1.head()
# Out:
#    Id       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df = df1.drop("Type",axis="columns")
df.head()
# Out:
#    Id       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Id"],df["Na"])

# %%
plt.plot(df["Id"],df["Na"])

# %%
sns.boxplot(df["Id"],df["Na"])

# %%
sns.heatmap(df)

# %%
sns.barplot(df["Id"],df["Na"])

# %%
sns.lineplot(df["Id"],df["Na"])

# %%
linechart?
# Out:
# Object `linechart` not found.

# %%
histogram?
# Out:
# Object `histogram` not found.

# %%
#sns.lineplot(df["Id"],df[("RI","Na","Mg","Al","Si","K","Ca","Ba","Fe")])

# %%
#sns.pointplot(x='"Id"',y='Na',df=df,color='red',alpha=0.8)

# %%
plt.pie(df["Id"],df[("RI","Na")])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('RI', 'Na')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-1e5b120871c6> in <module>
# ----> 1 plt.pie(df["Id"],df[("RI","Na")])
#
# ...
